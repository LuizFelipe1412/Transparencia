# %%
import pandas as pd
df_desp_original = pd.read_excel('/home/luiz/Documentos/Transparência/Transparencia/DESPESAS 2023.xlsx')

# %%
df_desp_original.describe()
# Out:
#           ANO          MES  COD_CLIENTE  COD_UNIDADE_GESTORA  \
# count  8960.0  8960.000000       8960.0          8960.000000
# mean   2023.0     2.453013          1.0        237544.943415
# min    2023.0     1.000000          1.0         50101.000000
# 25%    2023.0     2.000000          1.0        140101.000000
# 50%    2023.0     3.000000          1.0        250202.000000
# 75%    2023.0     3.000000          1.0        280101.000000
# max    2023.0     3.000000          1.0        500101.000000
# std       0.0     0.603430          0.0         82761.211334
#
#                         DATA_EMISSAO   COD_ELEMENTO  COD_TIPO_LICITACAO  \
# count                           8960    8960.000000         8960.000000
# mean   2023-01-31 15:43:13.928571392  339300.357589            7.982812
# min              2017-06-07 00:00:00  319001.000000            3.000000
# 25%              2023-02-07 00:00:00  339014.000000            6.000000
# ...

# %%
df_desp_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8960 entries, 0 to 8959
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ANO                   8960 non-null   int64
#  1   MES                   8960 non-null   int64
#  2   COD_CLIENTE           8960 non-null   int64
#  3   COD_UNIDADE_GESTORA   8960 non-null   int64
#  4   NOME_UNIDADE_GESTORA  8960 non-null   object
#  5   NOTA_EMPENHO          8960 non-null   object
#  6   DATA_EMISSAO          8960 non-null   datetime64[ns]
#  7   CPF_CNPJ              8960 non-null   object
#  8   NOME_CREDOR           8960 non-null   object
#  9   OBSERVACAO_EMPENHO    8960 non-null   object
#  10  COD_ELEMENTO          8960 non-null   int64
#  11  NOME_ELEMENTO         8960 non-null   object
#  12  COD_TIPO_LICITACAO    8960 non-null   int64
#  13  NOME_TIPO_LICITACAO   8960 non-null   object
#  14  IDT_DOCUMENTO         8960 non-null   int64
# ...

# %%
df_desp_original.head()
# Out:
#     ANO  MES  COD_CLIENTE  COD_UNIDADE_GESTORA  \
# 0  2023    2            1               230204
# 1  2023    2            1               230204
# 2  2023    2            1               230204
# 3  2023    2            1               230204
# 4  2023    2            1               230204
#
#                         NOME_UNIDADE_GESTORA NOTA_EMPENHO DATA_EMISSAO  \
# 0  AGÊNCIA DE DEFESA E INSPEÇÃO AGROPECUÁRIA  2023NE00001   2023-02-27
# 1  AGÊNCIA DE DEFESA E INSPEÇÃO AGROPECUÁRIA  2023NE00002   2023-02-27
# 2  AGÊNCIA DE DEFESA E INSPEÇÃO AGROPECUÁRIA  2023NE00003   2023-02-27
# 3  AGÊNCIA DE DEFESA E INSPEÇÃO AGROPECUÁRIA  2023NE00004   2023-02-27
# 4  AGÊNCIA DE DEFESA E INSPEÇÃO AGROPECUÁRIA  2023NE00005   2023-02-27
#
#       CPF_CNPJ                     NOME_CREDOR  \
# 0  58370510400   LUCIANA BARRETO ALMEIDA SILVA
# 1  17490189268  SELMA FIGUEIREDO MELO FERREIRA
# 2  24145718291      FABRICIO DE LIMA RODRIGUES
# 3  74584278253               BRUNO BRITO PINTO
# ...

# %%
col_desp = ['ANO', 'MES', 'NOME_UNIDADE_GESTORA', 'VAL_SALDO']
df_desp = df_desp_original[col_desp]
df_desp.head()
# Out:
#     ANO  MES                       NOME_UNIDADE_GESTORA  VAL_SALDO
# 0  2023    2  AGÊNCIA DE DEFESA E INSPEÇÃO AGROPECUÁRIA        110
# 1  2023    2  AGÊNCIA DE DEFESA E INSPEÇÃO AGROPECUÁRIA        330
# 2  2023    2  AGÊNCIA DE DEFESA E INSPEÇÃO AGROPECUÁRIA       1430
# 3  2023    2  AGÊNCIA DE DEFESA E INSPEÇÃO AGROPECUÁRIA        330
# 4  2023    2  AGÊNCIA DE DEFESA E INSPEÇÃO AGROPECUÁRIA        330

# %%
df_desp = df_desp.groupby(['ANO', 'MES', 'NOME_UNIDADE_GESTORA',], as_index=False)['VAL_SALDO'].sum()
df_desp.head()
# Out:
#     ANO  MES                          NOME_UNIDADE_GESTORA  VAL_SALDO
# 0  2023    1  CENTRO DE GESTÃO DA TECNOLOGIA DA INFORMAÇÃO      90879
# 1  2023    1           COMPANHIA DE ÁGUA E ESGOTO DO AMAPÁ    2074312
# 2  2023    1        CONTROLADORIA-GERAL DO ESTADO DO AMAPÁ      24273
# 3  2023    1           DEFENSORIA PÚBLICA DO ESTADO - DPE    56556676
# 4  2023    1                   FUNDO DE ASSISTÊNCIA SOCIAL    2907539
